# %%
setwd("C://bb//airbnb")

# %%
df <- read.table("./data/FF_train.csv", header=T, quote="\"", sep=",")

# %%
pr.class<-as.data.frame(sapply(df, class))
pr.type<-as.data.frame(sapply(df, typeof))

prot<-data.frame('name' = names(df),
                 'type' = as.vector(pr.type[[1]]), 
                 'class' = as.vector(pr.class[[1]]))

rownames(prot) <- prot$name
prot$min<-NA
prot$max<-NA
prot$unique<-NA

for (v in rownames(prot)){
  if (prot[v, 'class'] == 'numeric' | prot[v, 'class'] == 'integer'){
    prot[v, 'min']<-min(df[v])
  }
}

for (v in rownames(prot)){
  if (prot[v, 'class'] == 'numeric' | prot[v, 'class'] == 'integer'){
    prot[v, 'max']<-max(df[v])
  }
}

for (v in rownames(prot)){
  if (prot[v, 'class'] == 'numeric' | prot[v, 'class'] == 'integer'){
    prot[v, 'unique']<-length(unique(df[v]))
  }
}

options(scipen = 999)


write.csv(format(prot, digits = 0), "./data/protocol.csv",row.names = FALSE)
# Out:
# Warning message in `[<-.data.frame`(`*tmp*`, v, "unique", value = structure(list(:
# "replacement element 1 has 181468 rows to replace 1 rows"
# Warning message in `[<-.data.frame`(`*tmp*`, v, "unique", value = structure(list(:
# "replacement element 1 has 17446 rows to replace 1 rows"
# Warning message in `[<-.data.frame`(`*tmp*`, v, "unique", value = structure(list(:
# "replacement element 1 has 53 rows to replace 1 rows"
# Warning message in `[<-.data.frame`(`*tmp*`, v, "unique", value = structure(list(:
# "replacement element 1 has 6063 rows to replace 1 rows"
# Warning message in `[<-.data.frame`(`*tmp*`, v, "unique", value = structure(list(:
# "replacement element 1 has 1226 rows to replace 1 rows"
# Warning message in `[<-.data.frame`(`*tmp*`, v, "unique", value = structure(list(:
# "replacement element 1 has 1509 rows to replace 1 rows"
# Warning message in `[<-.data.frame`(`*tmp*`, v, "unique", value = structure(list(:
# "replacement element 1 has 8 rows to replace 1 rows"
# Warning message in `[<-.data.frame`(`*tmp*`, v, "unique", value = structure(list(:
# "replacement element 1 has 296 rows to replace 1 rows"
# Warning message in `[<-.data.frame`(`*tmp*`, v, "unique", value = structure(list(:
# "replacement element 1 has 296 rows to replace 1 rows"
# Warning message in `[<-.data.frame`(`*tmp*`, v, "unique", value = structure(list(:
# "replacement element 1 has 20723 rows to replace 1 rows"
# Warning message in `[<-.data.frame`(`*tmp*`, v, "unique", value = structure(list(:
# "replacement element 1 has 20773 rows to replace 1 rows"
# Warning message in `[<-.data.frame`(`*tmp*`, v, "unique", value = structure(list(:
# "replacement element 1 has 16 rows to replace 1 rows"
# Warning message in `[<-.data.frame`(`*tmp*`, v, "unique", value = structure(list(:
# "replacement element 1 has 20 rows to replace 1 rows"
# Warning message in `[<-.data.frame`(`*tmp*`, v, "unique", value = structure(list(:
# "replacement element 1 has 15 rows to replace 1 rows"
# Warning message in `[<-.data.frame`(`*tmp*`, v, "unique", value = structure(list(:
# "replacement element 1 has 18 rows to replace 1 rows"
# Warning message in `[<-.data.frame`(`*tmp*`, v, "unique", value = structure(list(:
# "replacement element 1 has 190 rows to replace 1 rows"
# Warning message in `[<-.data.frame`(`*tmp*`, v, "unique", value = structure(list(:
# "replacement element 1 has 281 rows to replace 1 rows"
# Warning message in `[<-.data.frame`(`*tmp*`, v, "unique", value = structure(list(:
# "replacement element 1 has 16 rows to replace 1 rows"
# Warning message in `[<-.data.frame`(`*tmp*`, v, "unique", value = structure(list(:
# "replacement element 1 has 105 rows to replace 1 rows"
# Warning message in `[<-.data.frame`(`*tmp*`, v, "unique", value = structure(list(:
# "replacement element 1 has 65 rows to replace 1 rows"
# Warning message in `[<-.data.frame`(`*tmp*`, v, "unique", value = structure(list(:
# "replacement element 1 has 208 rows to replace 1 rows"
# Warning message in `[<-.data.frame`(`*tmp*`, v, "unique", value = structure(list(:
# "replacement element 1 has 600 rows to replace 1 rows"
# Warning message in `[<-.data.frame`(`*tmp*`, v, "unique", value = structure(list(:
# "replacement element 1 has 58 rows to replace 1 rows"
# Warning message in `[<-.data.frame`(`*tmp*`, v, "unique", value = structure(list(:
# "replacement element 1 has 10 rows to replace 1 rows"
# Warning message in `[<-.data.frame`(`*tmp*`, v, "unique", value = structure(list(:
# "replacement element 1 has 10 rows to replace 1 rows"
# Warning message in `[<-.data.frame`(`*tmp*`, v, "unique", value = structure(list(:
# "replacement element 1 has 10 rows to replace 1 rows"
# Warning message in `[<-.data.frame`(`*tmp*`, v, "unique", value = structure(list(:
# "replacement element 1 has 10 rows to replace 1 rows"
# Warning message in `[<-.data.frame`(`*tmp*`, v, "unique", value = structure(list(:
# "replacement element 1 has 10 rows to replace 1 rows"
# Warning message in `[<-.data.frame`(`*tmp*`, v, "unique", value = structure(list(:
# "replacement element 1 has 10 rows to replace 1 rows"
# Warning message in `[<-.data.frame`(`*tmp*`, v, "unique", value = structure(list(:
# "replacement element 1 has 115 rows to replace 1 rows"
# Warning message in `[<-.data.frame`(`*tmp*`, v, "unique", value = structure(list(:
# "replacement element 1 has 1139 rows to replace 1 rows"
# Warning message in `[<-.data.frame`(`*tmp*`, v, "unique", value = structure(list(:
# "replacement element 1 has 18 rows to replace 1 rows"
